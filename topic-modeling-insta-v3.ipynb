# %%
#source https://www.analyticsvidhya.com/blog/2018/10/mining-online-reviews-topic-modeling-lda/

#import NLP modules
from nltk import FreqDist
import spacy

#modules for cleaning
import string

#imports for data handling
from pathlib import Path
import pandas as pd
pd.set_option("display.max_colwidth", 200)
#import numpy as np

#topic modeling
#import warnings
#disable DeprecationWarnings for gensim
#warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
#warnings.filterwarnings(action='ignore', category=DeprecationWarning)
import gensim
from gensim import corpora

#plotting
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pyLDAvis
import pyLDAvis.gensim
# Out:
# C:\Users\kvandoorn\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
#load spacy tokenizer
nlp = spacy.load('nl_core_news_sm', disable=['parser', 'ner'])

# %%
#define path for data
bestand = Path("social_posts.xlsx")
bestand_insta = Path("insta_posts_all.csv")

# %%
#load Dutch and Enlgish stopwords to list
stopbestand = Path(r"C:\Thuiswerken\Python\NL_stopwoorden.txt")
stopwoorden = [line.rstrip('\n') for line in open(stopbestand)]

stopbestand_EN = Path(r"Z:\Datalab\3 Werkwijze\Datasets\Textanalyse\EN_stopwoorden.txt")
stopwoorden_EN = [line.rstrip('\n') for line in open(stopbestand_EN)]

stopwoorden.extend(stopwoorden_EN)

# %%
#load file into pandas, select columns, drop empty and doubles
data_clean = pd.read_excel(bestand, usecols=('Hit Sentence','Source','Influencer'))
data_clean.columns = ['text','source','influencer']
data_clean.drop_duplicates(subset='text', inplace=True)
data_clean.dropna(axis=0, how='any', inplace=True)

# %%
#load instagram file
data_insta = pd.read_csv(bestand_insta, sep=';', usecols=('Hit Sentence','Source','Influencer'))
data_insta.columns = ['text','source','influencer']
data_insta.drop_duplicates(subset='text', inplace=True)
data_insta.dropna(axis=0, how='any', inplace=True)

# %%
#check instagram data
data_insta.head()
# Out:
#                                                                                                                                                                                                       text  \
# 0  , groeide het verhaal dat ik samen met de muizen wil vertellen.  Een verhaal over creativiteit, spelen en verbinding maken, maar waar ook duurzaamheid, ecologie en respect voor de natuur centraal ...
# 1  uit 304 RVS. ➡️TIG Gelast. ➡️Zeer hoge en duurzame kwaliteit.\n➡️Perfecte pasvorm, uitwisselbaar met originele downpipe\n➡️Uitvoerig op performance en duurzaamheid getest \nRVSuitlaatdelen.nl is o...
# 2  gewone bratwurst te onderscheiden. De structuur is ook erg goed. Zeker aan te raden! .\n.\n#sustainableliving #sustainability #duurzaam #duurzaamheid #vegan #vegetarian #savetheplanet #noplanb #no...
# 3                                                                                                 Heel veel plezier met je nieuwe Windmill Sophie! Vanaf nu rijdt Blitss officieel dus ook in Delft rond 😃
# 4          Het keurmerk voor de duurzame ondernemer⠀⠀⠀⠀⠀⠀⠀⠀⠀\n#duurzaamheid #duurzaam #sustainability  #bewustwording  #eerlijk #zzp #ondernemer#ondernemer #ondernemerschap\t⠀⠀⠀⠀⠀⠀⠀⠀⠀\n#socialmedia #mkb
#
#       source        influencer
# 0  Instagram       @muizennest
# 1  Instagram  @rvsuitlaatdelen
# 2  Instagram     @hansbertrams
# 3  Instagram        @blitss.eu
# 4  Instagram  @thewhitelabelnl

# %%
#add instagram data to main file
print(data_clean.shape)
data_clean = data_clean.append(data_insta, ignore_index=True)
print(data_clean.shape)
# Out:
# (42391, 3)
# (54016, 3)

# %%
#define punctuation and words particular for this case
#make function to clean data

duurzaamwords = ['duurzaam', 'verduurzamen', 'duurzaamheid', 'duurzame', 'qt', 'www', 'com']
punct = '!"$%&\'()*+,-./:;<=>?[\\]^_`{|}~‘’#'

def cleaning(post):
    post = " ".join(x for x in post.split() if x not in stopwoorden and x not in duurzaamwords and len(x) > 2)
    return post

# %%
#clean data: lowercase, remove \n remove url
data_clean['text'] = data_clean.text.str.lower().str.replace(r'\n',' ', regex=False).str.replace(r'http\S+', '', regex=True)
data_clean.head()
# Out:
#                                                                                                                                                                                                       text  \
# 0  de das.  aanvullende informatie de deelnemers verzamelen zich bij prinsenhof om samen naar het beginpunt van de wandeling te rijden. omdat het ivn voor duurzaamheid is, wordt het gestimuleerd om m...
# 1  betonpalen, 7.203 ton gewicht, 441 middenhuur- en koopappartementen, 4.000 m2 commerciële ruimten, 21 meter beneden nap, sociale duurzaamheid, energieneutraal en innovatie.   op het buiten ij, naa...
# 2  , waar je alles kunt vinden mbt tuinontwerp, tuinaanleg en tuinverlichting. maar ook de nieuwste snufjes op het gebied van oa regenwateropvang, duurzaamheid en zonne- energie zijn hier te vinden. ...
# 3  van ons gemeentehuis. natuurlijke materialen zorgen voor een goede isolatie, maar zijn gewoon ook esthetisch mooi! wil je meer weten? ontdek het ->   #lennikrenoveert #wijrenoveren #lennik #gemeen...
# 4  aan het werk bent.🥵  let op❗️ enkel te verkrijgen in onze shop  nu voor €9 ipv €14  eigenschappen  • echte metalen constructie voor duurzaamheid en veiligheid • laag stroomverbruik van 2,5 w • 360...
#
#      source                             influencer
# 0  Facebook                         Inwonersbesteo
# 1  Facebook  Gebr. van 't Hek Funderingstechnieken
# 2  Facebook                     Intratuin (Almelo)
# 3  Facebook                        Gemeente Lennik
# 4  Facebook                       Lalemansolutions

# %%
#clean data: remove anything not a letter
data_clean['text'] = data_clean.text.str.replace("[^a-zA-Z]", " ")
data_clean.head(50)
# Out:
#                                                                                                                                                                                                        text  \
# 0   de das   aanvullende informatie de deelnemers verzamelen zich bij prinsenhof om samen naar het beginpunt van de wandeling te rijden  omdat het ivn voor duurzaamheid is  wordt het gestimuleerd om m...
# 1   betonpalen        ton gewicht      middenhuur  en koopappartementen        m  commerci le ruimten     meter beneden nap  sociale duurzaamheid  energieneutraal en innovatie    op het buiten ij  naa...
# 2     waar je alles kunt vinden mbt tuinontwerp  tuinaanleg en tuinverlichting  maar ook de nieuwste snufjes op het gebied van oa regenwateropvang  duurzaamheid en zonne  energie zijn hier te vinden  ...
# 3   van ons gemeentehuis  natuurlijke materialen zorgen voor een goede isolatie  maar zijn gewoon ook esthetisch mooi  wil je meer weten  ontdek het       lennikrenoveert  wijrenoveren  lennik  gemeen...
# 4   aan het werk bent    let op   enkel te verkrijgen in onze shop  nu voor    ipv      eigenschappen    echte metalen constructie voor duurzaamheid en veiligheid   laag stroomverbruik van     w      ...
# 5   een tweede leven voor de voormalige twin towers  waar akzonobel en stibbe tot      kantoor hielden  daaraan werkt herontwikkelingsspecialist provast  samen met kcap architects   planners  onder de...
# 6   hebben de opgave dat alle gebouwen    in      van het aardgas af zijn en door een duurzame warmtebron verwarmd worden  tijdens de expeditie  duurzame warmte       is er gekeken naar opgaven en kan...
# 7   logistiek jeroen kiest graag voor duurzame oplossingen  zelf komt ie op de fiets naar z n werk en ook bij adri   zoon probeert hij duurzaamheid te integreren in de dagelijkse praktijk  die gloedni...
# 8   bouwen  afvalscheiding en elektrisch vervoer kunnen zij een belangrijke bijdrage leveren aan de ambities van nieuwegein op het gebied van duurzaamheid  daarom ondertekenden wethouder marieke schou...
# 9   design  food  health en service   wellness  design en comfort voor lifestyle geori nteerde reizigers met affiniteit voor kunst en cultuur  duurzaamheid en work life balance   individueel ingericht...
# 10   beforeandafter  afterandbefore  renoveren  verbouwen  verduurzamen  firmconstruction  aannemer  bouwbedrijf  firmconstruction  interiordesign  interiorarchitect  bricksstudio nl  bussum  laren  n...
# 11  van je kleur  stap    lacquer ontdek levendige  volle kleur   boordevol pigmenten stap    prostay gloss met deze top coat krijg je duurzaamheid die je van een gel gewend bent  de speciaal ontwikke...
# 12  ondanks het warme weer hebben de mannen van  suntech energy hard door gewerkt en liggen alle    zonnepanelen erop   verduurzamen  zonnepanelen  mooiwerk  bedrijfspand  zaak  laatdezonmaarschijnen ...
# 13     september de te gekke  broeinest x forbo  labdag   ben jij nieuwsgierig naar de allerleukste fabriek van het land  wil je meer weten over de duurzaamheid  productie  trends en collectie ontwikk...
# 14  dranouter festival wil een klimaatneutraal festival op poten zetten tegen      en eva helpt alvast om de catering te verduurzamen  dat betekent  meer veggie en vegan op het menu      eva westhoek ...
# 15  bij de morgen en de standaard en is mede initiatiefnemer van hart boven hard  een beweging van burgers en verenigingen die geloven in solidariteit  duurzaamheid en inclusiviteit   pretribru      s...
# 16  in het groen  dan biedt hasp o zepperen als groene satelliet temidden van de fruitgaarden een kwaliteitsvol alternatief  met eigen accenten rond duurzaamheid en engagement   zoek je een school waa...
# 17  wat is jouw kijk op kinderopvang  deel jouw visie op natuur en duurzaamheid voor de allerkleinsten  adviseur kinderopvang m la roept op om mee te denken  het vergroenen van de buitenruimte  met ki...
# 18  het is vakantietijd  een periode van relaxen  en misschien ook een moment om na te denken waar jij jouw woning nog kan verduurzamen  onderzoek nu de mogelijkheden en zorg dat jouw woning klaar is ...
# 19    wooncoach van het nieuwe wonen uit nieuwpoort    ik ben nog steeds bezig met mijn eigen huis  zelfs in een monumentaal pand kun je verduurzamen  intussen help ik anderen met de kennis en ervarin...
# 20  ons wagenpark is aan het verduurzamen  inmiddels hebben we al een aantal elektrische auto s op de parkeerplaats staan en van de week zijn daar twee mercedes benz evito s aan toegevoegd  deze busse...
# 21  materiaal is uiterst sterk en bovendien magnetronbestending tot       smaakneutraal  olie   vocht  en diepvriesbestendig   ontdek het gamma op onze webshop       duurzaamheid  suikerriet  disposab...
# 22  uv bestendig kleurvast milieuvriendelijk onderhoudsarm gaan een leven lang mee   keramische tegels  bestratingsmateriaal  tuin  tuininspiratie  sierbestrating  grind  split   bestrating  gardenofi...
# 23                                                                                                                                                                      tilburgse kermis en duurzaamheid
# 24  de laatste tijd hebben wij verschillende polls op facebook geplaatst met stellingen over duurzaamheid  zoals op de foto hieronder   in het bericht hieronder kun je nog stemmen op de laatste poll  ...
# 25  is uw bedrijf op zoek naar een nieuwe vestigingsplaats  draagt uw bedrijf duurzaamheid hoog in het vaandel  dan is het nieuw aan te leggen duurzaam bedrijventerrein doorn noord een mooie opportuni...
# 26  nieuw seizoen  meer aware   een collectie ontworpen van prachtige  milieuvriendelijke materialen  we erkennen dat duurzaamheid niet alleen een trend is  en aware by vero moda is een van onze bijdr...
# 27  expertise toe te passen voor projecten door heel nederland    samen met onze opdrachtgevers hebben we weer mooie oplossingen bedacht waarbij duurzaamheid  energietransitie en co  reductie het uitg...
# 28  in de recreatie  en vrijetijdsbranche  kenmerkend voor bedrijven met dit keurmerk is dat zij net dat stapje verder gaan bij het waarborgen van duurzaamheid binnen hun onderneming   bedrijven met e...
# 29  geopend en nu    jaar later zijn de vier kringloopwinkels van mamamini een begrip in groningen  we zijn nog lang niet klaar  want duurzaamheid en hergebruik zijn meer dan ooit een belangrijk onder...
# 30   wist je dat er bovenop het dak van de uithof      zonnepanelen zijn bevestigd    met alle opgewekte energie van onze zonnepanelen kunnen we onder andere de ijsbaan en de sneeuwbaan koel houden
# 31  onlangs was in de kranten te lezen dat sutfene in zutphen grote stappen wil zetten in duurzaamheid  communicatiemedewerker nick hagenbeek is in de studio om te vertellen welke stappen dat zijn en ...
# 32  het is vakantietijd  een periode van relaxen en even weg van de alledaagse sleur  wellicht is dit het moment om na te denken hoe jij jouw woning nog kan verduurzamen  onderzoek nu de mogelijkheden...
# 33                                                                       novitex combineert alle schoonheid  duurzaamheid en gebruiksgemak van novilon met de installatieflexibiliteit van een textielrug
# 34  t m vrijdag         albert heijn heeft maar liefst     nieuwe artikelen in het koffie en thee schap toegevoegd  nieuwe merken zoals o a starbucks  caf  vergano  ah excellent thee en australian the...
# 35  een perfecte maaibeeld en verbluffend gebruiksgemak  deze robuuste en oerdegelijke zitmaaier zet nieuwe normen voor ergonomie  ontwerp  duurzaamheid en gebruiksgemak  mulchmaaiers zijn vrijwel alt...
# 36  de eer en het genoegen om de nieuwste gepatenteerde biocleaner te presenteren         handgemaakt in spanje biocleaner        verhoogt de duurzaamheid van wimperextensions tot          vervangt de...
# 37  dan ben je er onderdeel van  ben jij een politicus die opstaat en zorgt dat de geldstromen in de goede richting gaan lopen  de richting die duurzaamheid beloont in plaats van afstraft  dan ben je ...
# 38  effect in de zonneschijn   en natuurlijk ook deze woensdag     korting op alles in de winkel    en niet te vergeten    gelukspoppetjes voor            fairtrade  eerlijkecadeautjes  eerlijkeprijze...
# 39   alkmaar  jubileum  magazine  circulaireeconomie   circulair  sloopwerk  duurzaam  bouwen  ontwerp  robot  mvo  duurzaamheid  asbest  asbestsanering  asbestos   familiebedrijf  sloopbedrijf  mater...
# 40  heb jij al foto s van jouw voortuin doorgestuurd       doe dit voor    juli en misschien val je in de prijzen  stuur een foto van jouw voorgevel of voortuin naar duurzaamheid oud turnhout be  verm...
# 41  hoe gaan we in nuenen om met duurzaamheid en de verplichte opgaven van het klimaatakkoord  wat is je zienswijze hierop  kom naar de inloop op maandag    juli van       tot       uur in het gemeent...
# 42   tijdelijke invulling  lijkt het nieuwe walhalla geworden omdat het leegstand bestrijdt en participatie steunt  maar er ontstaat een schrijnend gebrek aan duurzaamheid   lees nu de blog van lara s...
# 43  en   van de leukste manieren is water  of later op de avond pintjes natuurlijk    we zijn fan van samen spelen met water  maar duurzaamheid is ook een belangrijke waarde voor ons    daarom willen ...
# 44                          messenplank van      duurzaam eiken hout   voor wie zou dit een leuk cadeau zijn     shop     www woodlink nl product magnetische messenplank duurzaamheid  eiken  hout  cadeau
# 45  leuk interview in het  flow magazine  nr   van  jentedevries van  rotterzwam en   van de oprichters van de  krommunity over  duurzaamheid en wonen in een  tinyhouse  duurzaam  circulaireeconomieis...
# 46                        bij de gemeente het hogeland is ruimte voor pioniers en frisdenkers om samen een organisatie op te bouwen  wij zoeken een medewerker duurzaamheid   grondstoffen  iets voor jou
# 47  merchtem neemt deel aan  week van de  duurzamegemeente   ben jij in het dagelijks leven bezig met  armoede   gezondheid   milieu   duurzaamheid    of ken jij zo iemand  neem dan zeker een kijkje o...
# 48  wil je jouw huis verduurzamen  maar weet je niet waar of hoe je moet beginnen   brabant woont slim helpt  zelfs met kleine ingrepen verduurzaam je jouw woning en bespaar je geld     zet  s nachts ...
# 49  eerste hulp bij duurzaamheid tip         morgen is de laatste dag voor de normale loketten  dus voor je brandende vragen over energiebesparing  schone energie of groen zien we je graag morgen  vol...
#
#       source                                        influencer
# 0   Facebook                                    Inwonersbesteo
# 1   Facebook             Gebr. van 't Hek Funderingstechnieken
# 2   Facebook                                Intratuin (Almelo)
# 3   Facebook                                   Gemeente Lennik
# 4   Facebook                                  Lalemansolutions
# 5   Facebook                                  Amsterdam Zuidas
# 6   Facebook                                  Gemeente Brielle
# 7   Facebook                               Adri & Zoon Yerseke
# 8   Facebook                                            pen.nl
# 9   Facebook                                        TravelTeam
# 10  Facebook                                 Firm Construction
# 11  Facebook                           Da+Mooi Vermeulen Rhoon
# 12  Facebook                  Van Dijk Groenvoorzieningen B.V.
# 13  Facebook                                         Broeinest
# 14  Facebook                                               EVA
# 15  Facebook                                  Triënnale Brugge
# 16  Facebook                    Hasp-O Zepperen - SintAloysius
# 17  Facebook                                             ANMEC
# 18  Facebook                              Gemeente Halderberge
# 19  Facebook                              Gemeente Molenlanden
# 20  Facebook                                Hollander Techniek
# 21  Facebook                                          Salubris
# 22  Facebook                                   SierbetonOnline
# 23  Facebook                                      Kermisboeken
# 24  Facebook                               Gemeente Hardenberg
# 25  Facebook                               SOLVA Streekoverleg
# 26  Facebook                                         VERO MODA
# 27  Facebook                                    Noviton Prefab
# 28  Facebook                        Strandpaviljoen de Kwartel
# 29  Facebook                     Mamamini Goededoelenkringloop
# 30  Facebook                                         De Uithof
# 31  Facebook                                              B-FM
# 32  Facebook                              Gemeente Woensdrecht
# 33  Facebook                            Forbo Flooring Systems
# 34  Facebook               Albert Heijn Lange Nering Emmeloord
# 35  Facebook                                     Kerstma-Heida
# 36  Facebook                   Brand Lashes www.brandlashes.nl
# 37  Facebook  Praktijk voor Homeopathie en Bloedzuigertherapie
# 38  Facebook                               Wereldwinkel Zwolle
# 39  Facebook                            C.A. de Groot Groep BV
# 40  Facebook                             Gemeente Oud-Turnhout
# 41  Facebook                                   Gemeente Nuenen
# 42  Facebook                                       Kunstenpunt
# 43  Facebook                                      BALder Zomer
# 44  Facebook                                          Woodlink
# 45  Facebook                                      Puur Tafelen
# 46  Facebook                             Gemeente Het Hogeland
# 47  Facebook                                 Gemeente Merchtem
# 48  Facebook                              Gemeente Meierijstad
# 49  Facebook                                 Duurzaam Den Haag

# %%
#remove stopwords and particular words
data_clean['text'] = [cleaning(post) for post in data_clean['text']]

# %%
data_clean.head(10)
# Out:
#                                                                                                                                                                                                       text  \
# 0                                             das aanvullende informatie deelnemers verzamelen prinsenhof samen beginpunt wandeling rijden ivn gestimuleerd elkaar mee rijden verplicht deelnemers regelen
# 1                  betonpalen ton gewicht middenhuur koopappartementen commerci ruimten meter nap sociale energieneutraal innovatie naast ijburg verrijst straks wooncomplex sluishuis opdracht besix vorm
# 2                                 vinden mbt tuinontwerp tuinaanleg tuinverlichting nieuwste snufjes gebied regenwateropvang zonne energie vinden neem kijkje maak afspraak collega tuinontwerpstudio kijk
# 3                           gemeentehuis natuurlijke materialen zorgen goede isolatie esthetisch mooi weten ontdek lennikrenoveert wijrenoveren lennik gemeentehuis thuisinjegemeente hitte esthetischmooi
# 4                                             werk let verkrijgen shop ipv eigenschappen echte metalen constructie veiligheid laag stroomverbruik draaibaar luchtstroom overal naartoe richten usb voeding
# 5                                tweede leven voormalige twin towers akzonobel stibbe kantoor hielden daaraan werkt herontwikkelingsspecialist provast samen kcap architects planners naam amsterdam staat
# 6                                                                                     opgave gebouwen aardgas warmtebron verwarmd expeditie warmte gekeken opgaven kansen eiland verwarmen huizen gebouwen
# 7                          logistiek jeroen kiest graag oplossingen komt fiets werk adri zoon probeert integreren dagelijkse praktijk gloednieuwe volvo sluit naadloos binnenkort vinden nederlandse wegen
# 8  bouwen afvalscheiding elektrisch vervoer belangrijke bijdrage leveren ambities nieuwegein gebied ondertekenden wethouder marieke schouten namens gemeente nieuwegein green deal zorgspectrum donderd...
# 9  design food health service wellness design comfort lifestyle geori nteerde reizigers affiniteit kunst cultuur work life balance individueel ingerichte kamers casual local inspired design plek acht...
#
#      source                             influencer
# 0  Facebook                         Inwonersbesteo
# 1  Facebook  Gebr. van 't Hek Funderingstechnieken
# 2  Facebook                     Intratuin (Almelo)
# 3  Facebook                        Gemeente Lennik
# 4  Facebook                       Lalemansolutions
# 5  Facebook                       Amsterdam Zuidas
# 6  Facebook                       Gemeente Brielle
# 7  Facebook                    Adri & Zoon Yerseke
# 8  Facebook                                 pen.nl
# 9  Facebook                             TravelTeam

# %%
#function to plot most frequent terms

def freq_words(x, terms=30):
    all_words = ' '.join([text for text in x])
    all_words = all_words.split()
    
    fdist = FreqDist(all_words)
    words_df = pd.DataFrame({'word':list(fdist.keys()), 'count':list(fdist.values())})
    
    #selecting top20 most freq words
    d = words_df.nlargest(columns="count", n = terms)
    plt.figure(figsize=(20,5))
    ax = sns.barplot(data=d, x="word", y="count")
    ax.set(ylabel= 'Count')
    plt.show()

# %%
#freq_words(data_clean['text'])

# %%
#data_clean['text'] = data_clean['text'].str.replace('#duurzaamheid','')
#freq_words(data_clean['text'])

# %%
#convert posts to list
posts = data_clean['text'].tolist()

# %%
#tokenize posts
tokenized_posts = pd.Series(posts).apply(lambda x: x.split())
print(tokenized_posts[:1])
# Out:
# 0    [das, aanvullende, informatie, deelnemers, verzamelen, prinsenhof, samen, beginpunt, wandeling, rijden, ivn, gestimuleerd, elkaar, mee, rijden, verplicht, deelnemers, regelen]
# dtype: object

# %%
#function to lemmatize tokens
def lemmatization(texts):
    output = []
    for sent in texts:
        doc = nlp(' '.join(sent))
        output.append([token.lemma_ for token in doc if len(token.lemma_) > 2])
    return output

# %%
# %%time
#lemmatize tokens
posts_lemma = lemmatization(tokenized_posts)
# Out:
# Wall time: 3min 23s

# %% [markdown]
# # topic modeling LDA model

# %%
dictionary = corpora.Dictionary(posts_lemma)

# %%
doc_term_matrix = [dictionary.doc2bow(post) for post in posts_lemma]

# %%
LDA = gensim.models.ldamodel.LdaModel

# %%
lda_model = LDA(corpus=doc_term_matrix, id2word=dictionary, num_topics=7, random_state=100, chunksize=1000, passes=20)

# %%
lda_model.print_topics()
# Out:
# [(0,
#   '0.019*"maken" + 0.016*"goed" + 0.013*"gaan" + 0.012*"mens" + 0.010*"vinden" + 0.008*"mee" + 0.008*"komen" + 0.007*"willen" + 0.007*"jaar" + 0.007*"dag"'),
#  (1,
#   '0.009*"vegan" + 0.008*"sustainable" + 0.006*"together" + 0.006*"organic" + 0.006*"fietsen" + 0.006*"heerlijk" + 0.005*"wassen" + 0.005*"shirt" + 0.005*"solar" + 0.004*"fairtrad"'),
#  (2,
#   '0.009*"behandelen" + 0.008*"marketing" + 0.007*"fashion" + 0.007*"materiaal" + 0.006*"werkplek" + 0.005*"hoog" + 0.005*"doelstelling" + 0.005*"erin" + 0.005*"kleren" + 0.005*"dringen"'),
#  (3,
#   '0.009*"komen" + 0.009*"innovatie" + 0.008*"samen" + 0.008*"circulair" + 0.007*"gaan" + 0.007*"ding" + 0.006*"dag" + 0.006*"nieuw" + 0.006*"zien" + 0.005*"energie"'),
#  (4,
#   '0.018*"bio" + 0.013*"sustainability" + 0.010*"linken" + 0.008*"dag" + 0.008*"link" + 0.008*"sustainableliving" + 0.008*"green" + 0.008*"tips" + 0.007*"sustainable" + 0.007*"inspiratie"'),
#  (5,
#   '0.010*"utrecht" + 0.009*"nederland" + 0.007*"belegger" + 0.007*"rotterdam" + 0.006*"energie" + 0.005*"halen" + 0.005*"miljo" + 0.005*"niks" + 0.005*"procent" + 0.005*"zonnepark"'),
#  (6,
#   '0.009*"plastic" + 0.009*"sustainable" + 0.007*"sustainability" + 0.007*"interieur" + 0.007*"inspiration" + 0.006*"design" + 0.005*"zerowast" + 0.005*"greenlifestyl" + 0.005*"duurzaamwonen" + 0.005*"biologisch"')]

# %%
# # Visualize the topics
# pyLDAvis.enable_notebook()
# vis = pyLDAvis.gensim.prepare(lda_model, doc_term_matrix, dictionary)
# vis

# %%
# pyLDAvis.save_html(vis, 'topics_metinsta.html')
